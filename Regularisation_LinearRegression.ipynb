# %% [raw]
# # Implementation of Ridge, Lasso, Elestic Net Regularization

# %% [markdown]
# # Regularazation

# %%
# 1 mile = 1.6 km
# 1 gallon =  3.7 km

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop('name', axis = 1, inplace = True)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 393          82     usa
# 394          82  europe
# 395          82     usa
# 396          82     usa
# 397          82     usa

# %%
# what is ML pipeline
# 1. data Ingetion, 2. EDA, 3. Data Preperation, 4. seprete the x(I.V) & y(D.V),
# 5. train_test_split, 6. scalling(optional), then Build the model
# after build the model we can train & test the model with the help of some evalution matrices

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df.shape
# Out:
# (398, 8)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
# since we have not done outlier treatment , then better idea would be to 
# replace the missing value with median

df['horsepower'].median()
# Out:
# np.float64(93.5)

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df['horsepower']
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
# origin is the categrical column so we convert into numerical column 
# this process is known as Data Encoding

# %%
# DAta Encoding >> done with help of using dictionary
# how to map the dictionary with df['origin'] >> using map function
df['origin'] = df['origin'].map({"usa" :1, "japan" :2, "europe" :3})

# %%
df['origin']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    3
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
#df['origin'] = df['origin'].astype(int) # convert into integer data type

# %%
# sepertate the data into x(I.V) & y(D.V)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# dtype: object

# %%
X = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
# train test split with X & y

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 1)

# %%
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 350          4         105.0        63.0    2215          14.9          81
# 59           4          97.0        54.0    2254          23.5          72
# 120          4         121.0       112.0    2868          15.5          73
# 12           8         400.0       150.0    3761           9.5          70
# 349          4          91.0        68.0    1985          16.0          81
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 255          4         140.0        88.0    2720          15.4          78
# 72           8         304.0       150.0    3892          12.5          72
# 235          4          97.0        75.0    2265          18.2          77
# 37           6         232.0       100.0    3288          15.5          71
#
#      origin
# 350       1
# 59        3
# 120       3
# 12        1
# ...

# %%
X_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 174          6         171.0        97.0    2984          14.5          75
# 359          4         141.0        80.0    3230          20.4          81
# 250          8         318.0       140.0    3735          13.2          78
# 274          5         131.0       103.0    2830          15.9          78
# 283          6         232.0        90.0    3265          18.2          79
# ..         ...           ...         ...     ...           ...         ...
# 382          4         108.0        70.0    2245          16.9          82
# 39           8         400.0       175.0    4464          11.5          71
# 171          4         134.0        96.0    2702          13.5          75
# 271          4         156.0       105.0    2745          16.7          78
# 247          4          85.0        70.0    2070          18.6          78
#
#      origin
# 174       1
# 359       3
# 250       1
# 274       3
# ...

# %%
y_train
# Out:
# 350    34.7
# 59     23.0
# 120    19.0
# 12     15.0
# 349    34.1
#        ...
# 393    27.0
# 255    25.1
# 72     15.0
# 235    26.0
# 37     18.0
# Name: mpg, Length: 278, dtype: float64

# %%
y_test
# Out:
# 174    18.0
# 359    28.1
# 250    19.4
# 274    20.3
# 283    20.2
#        ...
# 382    34.0
# 39     14.0
# 171    24.0
# 271    23.2
# 247    39.4
# Name: mpg, Length: 120, dtype: float64

# %%
# crestion of simple Linear regression model

from sklearn.linear_model import LinearRegression
regression_model = LinearRegression()

# %%
regression_model
# Out:
# LinearRegression()

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.coef_
# Out:
# array([-0.31761423,  0.02623748, -0.01827076, -0.00748775,  0.05040673,
#         0.84709514,  1.51909584])

# %%
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.3176142302799293
# The coefficient for displacement is 0.02623748259907899
# The coefficient for horsepower is -0.01827076491312455
# The coefficient for weight is -0.007487750398361904
# The coefficient for acceleration is 0.05040673461971422
# The coefficient for model_year is 0.847095142706137
# The coefficient for origin is 1.519095838797506

# %%
# observations >> cofficients are relatively smaller, if one independent
# variable changes there will be not much difference in prediction
# this is sometime called as smoother model

# these features might not be contributing in model training

# %%
from sklearn.metrics import r2_score

y_pred_linear = regression_model.predict(X_test)
r2_linear = r2_score(y_test, y_pred_linear)
print(f"The R square of linear regression {r2_linear}")
# Out:
# The R square of linear regression 0.8348001123742284

# %% [markdown]
# # Regularized model

# %%
# Ridge regression 
# in practicle implementation lambda is alpha

from sklearn.linear_model import Ridge
ridge_regression_model = Ridge(alpha = 0.1)
ridge_regression_model
# Out:
# Ridge(alpha=0.1)

# %%
ridge_regression_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {ridge_regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.3170032101006747
# The coefficient for displacement is 0.026213249757983826
# The coefficient for horsepower is -0.018263252481448698
# The coefficient for weight is -0.007487326050213167
# The coefficient for acceleration is 0.05036896947443218
# The coefficient for model_year is 0.8470062938903183
# The coefficient for origin is 1.5174528285653954

# %%
# for ridge regression evelution 

y_pred_ridge = ridge_regression_model.predict(X_test)
r2_ridge = r2_score(y_test, y_pred_ridge)
print(f"The R square of ridge regression {r2_ridge}")
# Out:
# The R square of ridge regression 0.8348084889168355

# %%
# observation : we dont see much variation in coeff of ridge regression as comared to linear regression

# %% [markdown]
# # implement Lasso regression

# %%
from sklearn.linear_model import Lasso
lasso_regression_model = Lasso(alpha = 0.5)

# %%
lasso_regression_model
# Out:
# Lasso(alpha=0.5)

# %%
lasso_regression_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {lasso_regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.0062081988883003845
# The coefficient for horsepower is -0.011058382987169572
# The coefficient for weight is -0.00698267316802309
# The coefficient for acceleration is 0.0
# The coefficient for model_year is 0.744654952003819
# The coefficient for origin is 0.0

# %%
# obesrvation >> three features coefficient is 0, lasso helps in features selection

# %%
# evulation matrics
y_pred_lasso = lasso_regression_model.predict(X_test)
r2_pred = r2_score(y_test, y_pred_lasso)
print(f"The R square of lasso regression {r2_ridge}")
# Out:
# The R square of lasso regression 0.8348084889168355

# %% [markdown]
# # implementation of Elastic_net

# %%
from sklearn.linear_model import ElasticNet
ElasticNet_model = ElasticNet(alpha = 1, l1_ratio = 0.5)
ElasticNet_model
# Out:
# ElasticNet(alpha=1)

# %%
ElasticNet_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {ElasticNet_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.005888869953667572
# The coefficient for horsepower is -0.0124038749335701
# The coefficient for weight is -0.006934550516257633
# The coefficient for acceleration is 0.0
# The coefficient for model_year is 0.7133150744603874
# The coefficient for origin is 0.0

# %%
# test the model using Evalution matrics

y_pred_ElasticNet = ElasticNet_model.predict(X_test)
r2_ElasticNet = r2_score(y_test, y_pred_ElasticNet)
print(f"The R square of ElasticNet regression {r2_ridge}")
# Out:
# The R square of ElasticNet regression 0.8348084889168355

# %%
# regularisation with crossvaladation  

from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(cv = 5, verbose = 2)

# %%
lasso_cv
# Out:
# LassoCV(cv=5, verbose=2)

# %%
lasso_cv.fit(X_train, y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# ...

# %%
y_pred = lasso_cv.predict(X_test)
score = r2_score(y_test, y_pred)
print(f"The R square of LassoCV regression {score}")
# Out:
# The R square of LassoCV regression 0.808280598384475

# %%
# RidgeCV

from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(cv = 5 )
ridge_cv
# Out:
# RidgeCV(cv=5)

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(cv=5)

# %%
# test the model 
y_pred = ridge_cv.predict(X_test)
score = r2_score(y_test, y_pred)
print(f"The R square of RidgeCV regression {score}")
# Out:
# The R square of RidgeCV regression 0.8354145247502053

# %%
ridge_cv.get_params()  # to get parameter at which model is trained
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
# elsticnetcv

from sklearn.linear_model import ElasticNetCV
elastic_cv = ElasticNetCV(cv = 5)
elastic_cv
# Out:
# ElasticNetCV(cv=5)

# %%
elastic_cv.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
y_pred = elastic_cv.predict(X_test)
score = r2_score(y_test, y_pred)
print(f"The R square of elasticNetCV regression {score}")
# Out:
# The R square of elasticNetCV regression 0.792863401804916

# %% [raw]
# # CV hyperparameter tunning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, Ridge

# %%
# grid search cv for Lasso regularisation
# define the model
lasso = Lasso()
lasso
# Out:
# Lasso()

# %%
# grid search cv >> Dictionary with parameters names(str) as keys and Lists of 
# parameter settings to try as value

param_grid = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid
# Out:
# {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
grid_search = GridSearchCV(estimator=lasso, param_grid=param_grid, cv = 5, scoring = 'r2', verbose = 2)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}, scoring='r2',
#              verbose=2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# ...

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1}

# %%
grid_search.best_params_['alpha']
# Out:
# 0.1

# %%
grid_search.best_score_  # possible avg. score here
# Out:
# np.float64(0.7964209726696481)

# %%
grid_search.best_estimator_  # estimator >> model
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = grid_search.best_estimator_.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8345318641232302

# %%
# random search cv for Lasso
lasso = Lasso()
param_distributions = {'alpha' : [0.001, 0.01, 0.1, 10, 1, 100]}
random_Search_lasso = RandomizedSearchCV(estimator = lasso, param_distributions = param_distributions, cv = 5, n_iter=10, scoring = 'r2',verbose = 2 )

# %%
random_Search_lasso
# Out:
# RandomizedSearchCV(cv=5, estimator=Lasso(),
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 10, 1,
#                                                   100]},
#                    scoring='r2', verbose=2)

# %%
random_Search_lasso.fit(X_train, y_train)

# due to n_iter parameter in each cross validation random 3 parameter are selected
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# ...

# %%
random_Search_lasso.best_estimator_
# Out:
# Lasso(alpha=0.1)

# %%
random_Search_lasso.best_score_
# Out:
# np.float64(0.7964209726696481)

# %%
y_pred = random_Search_lasso.best_estimator_.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8345318641232302

# %% [markdown]
# # Ridge Grid Search CV

# %%
ridge = Ridge()
param_grid = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100]}
ridge = GridSearchCV(estimator = ridge, param_grid = param_grid, cv = 5, scoring = 'r2', verbose = 2)
ridge
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}, scoring='r2',
#              verbose=2)

# %%
ridge.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# ...

# %%
ridge.best_params_
# Out:
# {'alpha': 10}

# %%
ridge.best_estimator_
# Out:
# Ridge(alpha=10)

# %%
y_pred = ridge.best_estimator_.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8354145247502053

# %%
# Ridge randomized search cv

# %%
ridge = Ridge()
param_distributions = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100]}
ridge = RandomizedSearchCV(estimator = ridge, param_distributions= param_distributions, cv = 5, scoring = 'r2', n_iter = 3, verbose = 2)

# %%
ridge
# Out:
# RandomizedSearchCV(cv=5, estimator=Ridge(), n_iter=3,
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 1, 10,
#                                                   100]},
#                    scoring='r2', verbose=2)

# %%
ridge.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# ...

# %%
ridge.best_params_
# Out:
# {'alpha': 0.01}

# %%
ridge.best_score_
# Out:
# np.float64(0.7939892327199984)

# %%
ridge.best_estimator_
# Out:
# Ridge(alpha=0.01)

# %%
y_pred = ridge.best_estimator_.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8348009524594145

# %%
# elastic net Grid Search CV

elastic = ElasticNet()
param_grid = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100],
              'l1_ratio' : [0.1, 0.4, 0.9]}
elastic = GridSearchCV(estimator = elastic, param_grid = param_grid, cv = 5, scoring = 'r2', verbose = 2)
elastic.fit(X_train, y_train)
print(elastic.best_params_)

print(elastic.best_estimator_)

y_pred = elastic.best_estimator_.predict(X_test)

print(r2_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# ...

# %%
# elastic net Randomize Search CV

elastic = ElasticNet()
param_distributions = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100],
              'l1_ratio' : [0.1, 0.4, 0.9]}
elastic = RandomizedSearchCV(estimator = elastic, param_distributions = param_distributions, n_iter = 3, cv = 5, scoring = 'r2', verbose = 2)
elastic.fit(X_train, y_train)
print(elastic.best_params_)

print(elastic.best_estimator_)

y_pred = elastic.best_estimator_.predict(X_test)

print(r2_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# ...
